# %% [markdown]
# # waste classification using CNN

# %%
pip install opencv.python

# %%
pip install --upgrade pip

# %%
pip install tensorflow

# %%
import tensorflow
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
import warnings
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Activation,Dropout,Flatten,Dense,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array,load_img
from tensorflow.keras.utils import plot_model
from cv2 import cvtColor
from glob import glob

train_path="DATASET/TRAIN"
test_path="DATASET/TEST"
x_data = []
y_data = []
for category in glob(train_path+'/*'):
    for file in tqdm(glob(category+'/*')):
        img_arr = cv2.imread(file)
        img_arr = cvtColor(img_arr,cv2.COLOR_BGR2RGB)
        x_data.append(img_arr)
        y_data.append(category.split('/')[-1])
data = pd.DataFrame({'image':x_data,'label':y_data})
        
data.shape
plt.figure(figsize=(8, 6))
plt.pie(data['label'].value_counts(),labels=['Organic', 'Inorganic'],colors=['#FF6347', '#1E90FF'],autopct='%1.1f%%',startangle=90,shadow=True,explode=(0.1, 0),textprops={'color': 'white', 'fontsize': 14}
)

plt.title('Distribution of Organic vs Inorganic', fontsize=16, fontweight='bold')

plt.axis('equal')
plt.show()
# Out:
# ...
# 100%|██████████| 9999/9999 [00:02<00:00, 3972.48it/s]
